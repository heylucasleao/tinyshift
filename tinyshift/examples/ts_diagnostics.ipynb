# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))
from utilsforecast.preprocessing import fill_gaps
from utilsforecast.data import generate_series
from tinyshift.plot import stationarity_analysis, seasonal_decompose, pami
from tinyshift.series import adi_cv, foreca, hurst_exponent, regularity_index, theoretical_limit
from scipy import signal

# %%
df = generate_series(3, with_trend=True, static_as_categorical=False, seed=42, freq="D")

# %%
df.isnull().sum()

# %%
df = fill_gaps(df, freq="D", end="per_serie", id_col="unique_id", time_col="ds")

# %%
def forecastability(X):
    """
    Calculate forecastability metrics for a time series.
    """
    return {
        "foreCA": foreca(X),
        "theoretical_limit": theoretical_limit(X),
        "regularity_index": regularity_index(X, detrend=True),
        "adi_cv": adi_cv(X),
        "hurst_exponent": hurst_exponent(X),
    }

# %%
df.groupby("unique_id")["y"].apply(forecastability)

# %%
df["lag_1"] = df.groupby("unique_id")["y"].diff(1)
df["detrend"] = df.groupby("unique_id")["y"].transform(signal.detrend)
df["detrend_lag_7"] = df.groupby("unique_id")["detrend"].diff(7)

# %% [markdown]
# # ACF/PACF

# %%
df = df.set_index("ds")

# %%
for id in df["unique_id"].unique():
    stationarity_analysis(df.loc[df["unique_id"] == id, ["y", "lag_1", "detrend_lag_7"]], fig_type="png")

# %% [markdown]
# # Seasonal Decomposition

# %%
for id in df["unique_id"].unique():
    seasonal_decompose(
        df[df["unique_id"] == id]["y"],
        periods=7,
        fig_type="png",
    )

# %% [markdown]
# # PAMI

# %%
for id in df["unique_id"].unique():
    pami(df[df["unique_id"] == id]["y"], nlags=14, m=3, delay=1, normalize=True, fig_type="png")
