# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))
from utilsforecast.preprocessing import fill_gaps
from tinyshift.stats import remove_leading_zeros, is_obsolete, generate_lag
from tinyshift.series import fourier_seasonality, trend_significance
from tinyshift.plot import stationarity_analysis, pami, residual_analysis, seasonal_decompose
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import MSTL
from statsforecast.models import SeasonalNaive, AutoETS
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from mlforecast import MLForecast
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import rmse, mae, bias, cfe 
from tinyshift.series.stability import *
from tinyshift.series.interpolation import *
from tinyshift.series import wape, fva_rmae, pbias, score, forecast_instability, rmae, DMSTLWrapper

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(url, parse_dates=['Month'])
df["unique_id"] = "1"
df.rename(columns={"Month": "ds", "Passengers": "y"}, inplace=True)
df = fill_gaps(df, freq="ME", end="per_serie", id_col="unique_id", time_col="ds")
df = df.groupby("unique_id")[df.columns].apply(remove_leading_zeros).reset_index(drop=True)
df = fourier_seasonality(df, "ds", seasonality=["monthly"])
days_obsoletes=180
obsolete_series = df.groupby("unique_id")[df.columns].apply(is_obsolete, days_obsoletes)
obsolote_ids = obsolete_series[obsolete_series].index.tolist()
assert len(obsolote_ids) == 0, f"Obsolete series found: {obsolote_ids}"
df.groupby("unique_id")["y"].apply(trend_significance)
# Out:
# unique_id
# 1    (0.853638165603188, 4.020274506593391e-61)
# Name: y, dtype: object

# %%
metrics = [rmse, mae, bias, cfe, wape, pbias, score, forecast_instability]

# %%
df.isnull().sum()
# Out:
# unique_id      0
# ds             0
# y              0
# monthly_sin    0
# monthly_cos    0
# dtype: int64

# %%
horizon = 12
train = df[:-horizon]
test = df[-horizon:]

# %%
seasonal_decompose(np.log(df["y"]),periods=12,fig_type="png")

# %% [markdown]
# # Decomposition + ML

# %% [markdown]
# Linear Detrend + ML (Seasonality + Resiual)

# %%
from signal import signal

import pandas as pd
from sklearn.linear_model import LinearRegression
from pandas.tseries.frequencies import to_offset

class LinearRegressionDetrendModels():
    def __init__(self):
        self.models = {} 
        self.last_time_index = {}
        self.freq = None
        self.last_index = {}
    
    def fit(self, df_train, freq, id_col="unique_id", time_col="ds", target_col="y"):
        forecasts = []

        for uid, group in df_train.groupby(id_col):
            self.last_time_index[uid] = group[time_col].max() 
            time_index = np.arange(len(group)).reshape(-1, 1)
            self.last_index[uid] = time_index[-1][0]
            trend_model = LinearRegression()
            trend_model.fit(time_index, group[target_col])
            self.models[uid] = trend_model
            self.freq = freq
            trend_forecast = trend_model.predict(time_index)
            uid_forecast = pd.DataFrame({
                id_col: uid,
                time_col: group[time_col],
                "trend": trend_forecast,
            })
            forecasts.append(uid_forecast)

        return pd.concat(forecasts).reset_index(drop=True)

    def predict(self, h, id_col="unique_id", time_col="ds"):
        
        forecasts = []
        
        for uid in self.models:

            future_dates = pd.date_range(
                start=self.last_time_index[uid] + to_offset(self.freq),
                periods=h,
                freq=self.freq
            )
            time_index = np.arange(self.last_index[uid] + 1, self.last_index[uid] + h + 1).reshape(-1, 1)
            trend_forecast = self.models[uid].predict(time_index)

            uid_forecast = pd.DataFrame({
                id_col: uid,
                time_col: future_dates,
                "trend": trend_forecast,
            })
            forecasts.append(uid_forecast)
                
        return pd.concat(forecasts).reset_index(drop=True)

# %%
detrend_linear = LinearRegressionDetrendModels()
train = train.copy()
train["log_y"] = np.log(train["y"])
trend = detrend_linear.fit(train, freq="MS", target_col="log_y")

# %%
train = pd.merge(train, trend, on=["unique_id", "ds"], how="inner")
train["y_log_detrend"] = train["log_y"] - train["trend"]
train["lag_1"] = generate_lag(train["y_log_detrend"], lag=1)
train["lag_12"] = generate_lag(train["lag_1"], lag=12)

# %%
stationarity_analysis(train[["y_log_detrend", "lag_1", "lag_12"]], nlags=30, fig_type="png")

# %%
train.drop(columns=["lag_1", "lag_12"], inplace=True)

# %%
def compute_lgbm_params(N: int):
    max_depth = int(np.ceil(np.log2(N) - 1))
    subsample_freq = 1
    colsample_bytree = 0.7
    n_estimators = 1000
    reg_lambda = 0.2
    reg_alpha = 0.2
    metric = "mae"
    learning_rate = 0.05
    min_child_samples = max(20, int(np.cbrt(N)))
    n_jobs = -1
    random_state = 42

    return {
        "max_depth": int(max_depth),
        "subsample_freq": subsample_freq,
        "colsample_bytree": colsample_bytree,
        "n_estimators": n_estimators,
        "metric": metric,
        "learning_rate": learning_rate,
        "num_leaves": 40,
        "min_child_samples": min_child_samples,
        "reg_alpha": reg_alpha,
        "reg_lambda": reg_lambda,
        "objective": "regression_l2",
        "n_jobs": n_jobs,
        "random_state": random_state
    }
config = compute_lgbm_params(len(train))
models = [LGBMRegressor(**config, verbosity=-1), RandomForestRegressor(n_estimators=100, random_state=42)]

# %% [markdown]
# ## MSTL + ML

# %%
def convert_to_dataframe(result: MSTL) -> pd.Series:
        """
        Reconstructs the original time series from its MSTL decomposition components.

        Parameters
        ----------
        result : MSTL
            Fitted MSTL object containing the decomposition components.

        Returns
        -------
        pandas.Series
            Reconstructed time series obtained by summing the trend, seasonal, and residual components.
        """
        df = pd.DataFrame()
        df["data"] = result.observed
        df["trend"] = result.trend
        if isinstance(result.seasonal, pd.Series):
            df["seasonal"] = result.seasonal
        else:
            for seasonal_col in result.seasonal.columns:
                df[seasonal_col] = result.seasonal[seasonal_col]
        df["resid"] = result.resid

        return df

# %%
mstl = MSTL(train["y"], periods=12).fit()
decomp = convert_to_dataframe(mstl)

# %%
stationarity_analysis(decomp["resid"], nlags=30, fig_type="png")

# %%
pami(decomp["resid"], nlags=30, fig_type="png", m=3, normalize=True)

# %%
season_length = 12
seasonal = SeasonalNaive(season_length=season_length)
trend = AutoETS(season_length=season_length, model="MMN") # Seasonality already removed, so 'S' is N!
mf = MLForecast(
    models=models,
    freq="MS",
    lags=[1, 3],
)
dmstl = DMSTLWrapper(
    seasonal_model=seasonal,
    mf_resid=mf,
    season_length=12
)

# %%
dmstl.fit(train[["unique_id", "ds", "y"]], target_col="y")
# Out:
# DMSTLWrapper(mf_resid=MLForecast(models=[LGBMRegressor, RandomForestRegressor], freq=MS, lag_features=['lag1', 'lag3'], date_features=[], num_threads=1),
#              season_length=12, seasonal_model=SeasonalNaive)

# %%
result = dmstl.predict(h=12, level=0.95)
result["y"] = test["y"].values
# Out:
# /home/heylucasleao/tinyshift/.venv/lib/python3.12/site-packages/mlforecast/forecast.py:1542: UserWarning:
#
# Please rerun the `fit` method passing a proper value to prediction intervals to compute them.

# %%
evaluate(result, 
         metrics=metrics, 
         models=["LGBMRegressor", "RandomForestRegressor"], 
         id_col="unique_id", 
         time_col="ds", 
         target_col="y")
# Out:
#   unique_id                metric  LGBMRegressor  RandomForestRegressor
# 0         1                  rmse      14.521539              15.635627
# 1         1                   mae      11.333683              11.544834
# 2         1                  bias       3.813138               5.572988
# 3         1                   cfe      45.757661              66.875857
# 4         1                  wape       2.380192               2.424536
# 5         1                 pbias       0.800799               1.170386
# 6         1                 score       3.180992               3.594922
# 7         1  forecast_instability       9.787882               9.577798

# %%
result["residual_dmstl_lgbm"] = result["y"].values - result["LGBMRegressor"].values
result["residual_dmstl_rf"] = result["y"].values - result["RandomForestRegressor"].values

# %%
residual_analysis(result[["residual_dmstl_lgbm", "residual_dmstl_rf"]], nlags=30, fig_type="png")

# %%
seasonality_val = 12
rmssc_h_result = rmssch(train["y"], result["LGBMRegressor"], seasonality_val)
mac_h_result = mach(result["LGBMRegressor"])
print(f"MAC(H) (Horizontal Stability): {mac_h_result:.6f}")
print(f"RMSSC(H) (Horizontal Stability - Squared): {rmssc_h_result:.6f}")
# Out:
# MAC(H) (Horizontal Stability): 44.882345
# RMSSC(H) (Horizontal Stability - Squared): 1.510142

# %%
rmssc_h_result = rmssch(train["y"], result["LGBMRegressor"], seasonality_val)
mac_h_result = mach(result["LGBMRegressor"])
print(f"MAC(H) (Horizontal Stability): {mac_h_result:.6f}")
print(f"RMSSC(H) (Horizontal Stability - Squared): {rmssc_h_result:.6f}")
# Out:
# MAC(H) (Horizontal Stability): 44.882345
# RMSSC(H) (Horizontal Stability - Squared): 1.510142

# %% [markdown]
# ## Horizontal Partial Interpolation

# %%
result["y_pred_pi"] = dmstl.predict(h=12, stabilization_method="hpi", w_s=0.8)["LGBMRegressor"]
rmssc_h_result = rmssch(train["y"], result["y_pred_pi"], seasonality_val)
mac_h_result = mach(result["y_pred_pi"])
print(f"MAC(H) (Horizontal Stability): {mac_h_result:.6f}")
print(f"RMSSC(H) (Horizontal Stability - Squared): {rmssc_h_result:.6f}")
# Out:
# MAC(H) (Horizontal Stability): 36.238725
# RMSSC(H) (Horizontal Stability - Squared): 1.320522

# %% [markdown]
# ## Horizontal Full Interpolation

# %%
result["y_pred_fi"] = dmstl.predict(h=12, stabilization_method="hfi", w_s=0.8)["LGBMRegressor"]
rmssc_h_result = rmssch(train["y"], result["y_pred_fi"], seasonality_val)
mac_h_result = mach(result["y_pred_fi"])
print(f"MAC(H) (Horizontal Stability): {mac_h_result:.6f}")
print(f"RMSSC(H) (Horizontal Stability - Squared): {rmssc_h_result:.6f}")
# Out:
# MAC(H) (Horizontal Stability): 12.624432
# RMSSC(H) (Horizontal Stability - Squared): 0.449003

# %%
fva_rmae(result["y"].values, result["LGBMRegressor"].values, nlags=1, baseline_type="naive")
# Out:
# 0.2553158358673343

# %%
fva_rmae(result["y"].values, result["LGBMRegressor"].values, baseline_type="moving_average", window_size=3)
# Out:
# 0.17799480373595783

# %% [markdown]
# # Prediction Intervals

# %%
from mlforecast.utils import PredictionIntervals

# %%
prediction_intervals = PredictionIntervals(
    n_windows=3,
    h=14
)
dmstl = DMSTLWrapper(
    seasonal_model=seasonal,
    mf_resid=mf,
    season_length=12
)
dmstl.fit(train[["unique_id", "ds", "y"]], target_col="y", prediction_intervals=prediction_intervals)
forecasts = dmstl.predict(
    h=14, 
    level=[0.05, 95]  
)

# %%
forecasts
# Out:
#    unique_id         ds  LGBMRegressor  RandomForestRegressor  \
# 0          1 1960-01-01     417.431484             420.522752
# 1          1 1960-02-01     400.355283             400.169388
# 2          1 1960-03-01     454.118310             456.317325
# 3          1 1960-04-01     445.065148             449.495789
# 4          1 1960-05-01     465.702452             469.644726
# 5          1 1960-06-01     536.668465             534.791739
# 6          1 1960-07-01     603.221414             601.967738
# 7          1 1960-08-01     610.917636             609.899736
# 8          1 1960-09-01     520.015129             516.515116
# 9          1 1960-10-01     456.887720             459.268935
# 10         1 1960-11-01     404.110447             411.429427
# 11         1 1960-12-01     445.264172             450.853186
# 12         1 1961-01-01     468.727614             467.969502
# 13         1 1961-02-01     450.459382             451.803295
#
#     LGBMRegressor-lo-95  LGBMRegressor-lo-0.05  LGBMRegressor-hi-0.05  \
# 0            408.416018             417.429517             417.433451
# 1            385.260878             400.351211             400.359355
# 2            448.757376             454.113482             454.123139
# 3            440.587616             445.062348             445.067948
# 4            460.953831             465.698269             465.706634
# 5            533.113869             536.667377             536.669553
# 6            594.676772             603.201747             603.241082
# 7            597.061422             610.899453             610.935819
# 8            505.291767             520.010016             520.020243
# 9            451.193858             456.877801             456.897639
# 10           398.663563             404.108497             404.112397
# 11           434.039585             445.262203             445.266141
# 12           462.485333             468.725517             468.729712
# 13           444.451033             450.456691             450.462074
#
#     LGBMRegressor-hi-95  RandomForestRegressor-lo-95  \
# 0            426.446951                   408.736871
# 1            415.449688                   386.747893
# 2            459.479245                   449.866874
# 3            449.542679                   442.712527
# 4            470.451073                   464.257101
# 5            540.223061                   529.188325
# 6            611.766057                   589.244064
# 7            624.773851                   595.636381
# 8            534.738492                   508.697377
# 9            462.581582                   455.718357
# 10           409.557331                   405.689123
# 11           456.488759                   440.972381
# 12           474.969896                   458.255513
# 13           456.467731                   448.800538
#
#     RandomForestRegressor-lo-0.05  RandomForestRegressor-hi-0.05  \
# 0                      420.519629                     420.525875
# 1                      400.150464                     400.188313
# 2                      456.313000                     456.321649
# 3                      449.490942                     449.500636
# 4                      469.640603                     469.648849
# 5                      534.791038                     534.792441
# 6                      601.965810                     601.969666
# 7                      609.891505                     609.907968
# 8                      516.511408                     516.518824
# 9                      459.268314                     459.269556
# 10                     411.427345                     411.431510
# 11                     450.837498                     450.868873
# 12                     467.967090                     467.971914
# 13                     451.801330                     451.805259
#
#     RandomForestRegressor-hi-95
# 0                    432.308633
# 1                    413.590883
# 2                    462.767775
# 3                    456.279051
# 4                    475.032350
# 5                    540.395154
# 6                    614.691412
# 7                    624.163092
# 8                    524.332855
# 9                    462.819513
# 10                   417.169732
# 11                   460.733990
# 12                   477.683491
# 13                   454.806052
